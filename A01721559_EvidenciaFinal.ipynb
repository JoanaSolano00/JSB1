# %% [markdown]
# <a href="https://colab.research.google.com/github/JoanaSolano00/JSB1/blob/main/A01721559_EvidenciaFinal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## JOANA SOLANO BEJARANO A01721559 - EVIDENCIA FINAL

# %% [markdown]
# ## Satisfacción de los clientes de la aerolinea

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
from sklearn import linear_model
import statsmodels.api as sm

# %%
df= pd.read_csv('https://raw.githubusercontent.com/JoanaSolano00/JSB1/main/test.csv')
df.head()
# Out:
#    Unnamed: 0     id  Gender      Customer Type  Age   Type of Travel  \
# 0           0  19556  Female     Loyal Customer   52  Business travel
# 1           1  90035  Female     Loyal Customer   36  Business travel
# 2           2  12360    Male  disloyal Customer   20  Business travel
# 3           3  77959    Male     Loyal Customer   44  Business travel
# 4           4  36875  Female     Loyal Customer   49  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0       Eco              160                      5
# 1  Business             2863                      1
# 2       Eco              192                      2
# 3  Business             3377                      0
# 4       Eco             1182                      2
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  1  ...                       4
# ...

# %% [markdown]
# ## Descripcion Base de datos
# Este conjunto de datos contiene una encuesta de satisfacción de pasajeros de líneas aéreas. Son encuestadas en total 25975 personas.

# %%
print(*df.columns, 
      sep = '\n')
# Out:
# Unnamed: 0
# id
# Gender
# Customer Type
# Age
# Type of Travel
# Class
# Flight Distance
# Inflight wifi service
# Departure/Arrival time convenient
# Ease of Online booking
# Gate location
# Food and drink
# Online boarding
# Seat comfort
# Inflight entertainment
# On-board service
# Leg room service
# Baggage handling
# Checkin service
# Inflight service
# Cleanliness
# Departure Delay in Minutes
# Arrival Delay in Minutes
# satisfaction

# %% [markdown]
# ## Descripcion de Todas las Variables
# Género: Género de los pasajeros (Femenino, Masculino)
# Tipo de cliente: el tipo de cliente (cliente fiel, cliente desleal)
# Edad: La edad real de los pasajeros.
# Tipo de Viaje: Propósito del vuelo de los pasajeros (Viaje Personal, Viaje de Negocios)
# Clase: Clase de viaje en el avión de los pasajeros (Business, Eco, Eco Plus)
# Distancia de vuelo: la distancia de vuelo de este viaje
# Servicio wifi a bordo: Nivel de satisfacción del servicio wifi a bordo (0: No aplicable; 1-5) Hora de salida/llegada conveniente: Nivel de satisfacción de la hora de salida/llegada conveniente Facilidad de reserva en línea: Nivel de satisfacción de la reserva en línea Ubicación de la puerta: nivel de satisfacción de la ubicación de la puerta
# Alimentos y bebidas: Nivel de satisfacción de Alimentos y bebidas
# Embarque en línea: Nivel de satisfacción del embarque en línea
# Comodidad del asiento: Nivel de satisfacción de Confort del asiento
# Entretenimiento a bordo: Nivel de satisfacción del entretenimiento a bordo
# Servicio a bordo: Nivel de satisfacción del servicio a bordo
# Servicio de sala de piernas: Nivel de satisfacción del servicio de sala de piernas
# Manejo de equipaje: Nivel de satisfacción del manejo de equipaje
# Servicio de Check-in: Nivel de satisfacción del servicio de Check-in Servicio a bordo: Nivel de satisfacción del servicio a bordo
# Limpieza: Nivel de satisfacción de Limpieza
# Retraso de salida en minutos: Minutos de retraso en la salida
# Retraso de llegada en minutos: Minutos de retraso en la llegada
# Satisfacción: Nivel de satisfacción de la aerolínea (Satisfacción, neutral o insatisfacción)

# %% [markdown]
# ## Descripción de las Variables seleccionadas
# - Age: Variable numérica, explica la edad de los participantes. (7-85 años
# - Gender: Variable categórica, Explica los géneros de los participantes. (Female, Male)
# - Satisfaction: Variable Categórica, explica la satisfacción de los clientes: (Satisfacción: más alta, neutral: medio o insatisfacción: más baja)
# - On-board service: Variable Numérica, Nivel de satisfacción del servicio a bordo, del 1-5.
#
# - Checkin service: Variable numérica. Nivel de satisfacción del servicio de Check-in del 1-5.
#
# - Inflight wifi service: Variable numérica. Nivel de satisfacción del servicio wifi a bordo del 1-5.
#
# - Inflight entertainment:Variable numérica. Nivel de satisfacción del servicio de entretenimiento del 1-5.
#
# - Baggage handling:Variable numérica. Nivel de satisfacción del servicio de maletas del 1-5.
#
# - Flight Distance: Variable numérica, explica la distancia del viaje.
#
# - Customer Type: Variable Categórica. Propósito del vuelo de los pasajeros (Viaje Personal, Viaje de Negocios).
#
# - Class: Variable categórica, explica la clase de viaje en el avión de los pasajeros (Business, Eco, Eco Plus).
#
# - Cleanliness: Variable numérica. Nivel de satisfacción del servicio de limpieza del 1-5.

# %% [markdown]
# ## Empresa, sector de la sociedad, organismo descentralizado, gobierno, etc. que estaría interesado en las preguntas
# Todas las aerolíneas estarían interesadas como Viva Aerobus, Delta, Copa Airlines, Aeroméxico, entre otras.

# %%
dff= df.loc[:,['Age', 'Gender', 'satisfaction']]
dff
# Out:
#        Age  Gender             satisfaction
# 0       52  Female                satisfied
# 1       36  Female                satisfied
# 2       20    Male  neutral or dissatisfied
# 3       44    Male                satisfied
# 4       49  Female                satisfied
# ...    ...     ...                      ...
# 25971   34    Male  neutral or dissatisfied
# 25972   23    Male                satisfied
# 25973   17  Female  neutral or dissatisfied
# 25974   14    Male                satisfied
# 25975   42  Female  neutral or dissatisfied
#
# [25976 rows x 3 columns]

# %%
def gEdades(x):
  if 0<= x <=18:
    return '<=18'
  elif 18< x <= 35:
    return '18-35'
  elif 35<x<=60:
    return '35-60'
  else: 
    return '>=60'

# %%
gEdades(45)
# Out:
# '35-60'

# %%
df.Age
# Out:
# 0        52
# 1        36
# 2        20
# 3        44
# 4        49
#          ..
# 25971    34
# 25972    23
# 25973    17
# 25974    14
# 25975    42
# Name: Age, Length: 25976, dtype: int64

# %%
dff['AgeGP']=dff.apply(lambda tbl: gEdades(tbl['Age']),
                     axis=1)

# %%
ndf=dff[['Age','Gender','satisfaction','AgeGP']]

# %%
ndf=ndf.dropna()

# %%
ndf.shape
# Out:
# (25976, 4)

# %%
df.shape
# Out:
# (25976, 25)

# %%
dff
# Out:
#        Age  Gender             satisfaction  AgeGP
# 0       52  Female                satisfied  35-60
# 1       36  Female                satisfied  35-60
# 2       20    Male  neutral or dissatisfied  18-35
# 3       44    Male                satisfied  35-60
# 4       49  Female                satisfied  35-60
# ...    ...     ...                      ...    ...
# 25971   34    Male  neutral or dissatisfied  18-35
# 25972   23    Male                satisfied  18-35
# 25973   17  Female  neutral or dissatisfied   <=18
# 25974   14    Male                satisfied   <=18
# 25975   42  Female  neutral or dissatisfied  35-60
#
# [25976 rows x 4 columns]

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                            0
# id                                    0
# Gender                                0
# Customer Type                         0
# Age                                   0
# Type of Travel                        0
# Class                                 0
# Flight Distance                       0
# Inflight wifi service                 0
# Departure/Arrival time convenient     0
# Ease of Online booking                0
# Gate location                         0
# Food and drink                        0
# Online boarding                       0
# Seat comfort                          0
# Inflight entertainment                0
# On-board service                      0
# Leg room service                      0
# Baggage handling                      0
# Checkin service                       0
# Inflight service                      0
# Cleanliness                           0
# Departure Delay in Minutes            0
# ...

# %%
counts=pd.pivot_table(index=['AgeGP'],
               data= ndf, 
               aggfunc='count',
               values = 'satisfaction'
              )

# %%
counts.index
# Out:
# Index(['18-35', '35-60', '<=18', '>=60'], dtype='object', name='AgeGP')

# %%
total=counts.satisfaction.sum()

# %%
counts['%'] = (counts.iloc[:,0]/total)
counts
# Out:
#        satisfaction         %
# AgeGP
# 18-35          8123  0.312712
# 35-60         13614  0.524099
# <=18           2161  0.083192
# >=60           2078  0.079997

# %%
counts.reset_index()
# Out:
#    AgeGP  satisfaction         %
# 0  18-35          8123  0.312712
# 1  35-60         13614  0.524099
# 2   <=18          2161  0.083192
# 3   >=60          2078  0.079997

# %%
color_list=['salmon','lavender', 'yellowgreen','skyblue','lightgreen']
explode_dist=[0.03,0.04,0.03,0.05]

# %% [markdown]
# ## Pregunta 1. ¿Cuál es la calificación de satisfacción por grupo de edades?

# %%
import matplotlib.pyplot as plt

# %%
counts['satisfaction'].plot(kind='pie',
                      figsize=(15,6),
                      autopct='%1.2F%%',
                      labels=None,
                      pctdistance=1.1,
                      startangle=90,
                      colors= color_list,
                      explode=explode_dist
                      )
plt.legend(labels = counts.index,
           bbox_to_anchor=(1.2,1.0)
           )
plt.title('Age group of respondents', y=1.15);

# %% [markdown]
# ## 1. Conclusión
# La mayor cantidad de personas que respondieron tienen edad entre 35-60 años.
# El grupo de personas que menos respondio fueron de edades mayor o igual a 60.

# %% [markdown]
# ## Pregunta 2 ¿Cuál es la cantidad de respuestas respecto a cada grupo de edades basada en el Genero?

# %%
dff
# Out:
#        Age  Gender             satisfaction  AgeGP
# 0       52  Female                satisfied  35-60
# 1       36  Female                satisfied  35-60
# 2       20    Male  neutral or dissatisfied  18-35
# 3       44    Male                satisfied  35-60
# 4       49  Female                satisfied  35-60
# ...    ...     ...                      ...    ...
# 25971   34    Male  neutral or dissatisfied  18-35
# 25972   23    Male                satisfied  18-35
# 25973   17  Female  neutral or dissatisfied   <=18
# 25974   14    Male                satisfied   <=18
# 25975   42  Female  neutral or dissatisfied  35-60
#
# [25976 rows x 4 columns]

# %%
plot_order = [ '<=18','18-35', '35-60', '>=60']

# %%
g = sns.catplot(x="AgeGP", 
            kind="count", 
            hue = 'Gender',
            data=dff,
            #index=['<=20','21-30','31-40', '41-50']
            #order=df.model.value_counts().index
                height=10, 
                aspect=1.5,
                palette=["orchid", "lightsalmon"],
                order = plot_order,
           )
g.fig.set_size_inches(7.2, 5)
g.fig.subplots_adjust(top=0.81, right=0.86)

ax = g.facet_axis(0, 0)

###for c in ax.containers:
###   labels = [f'{(v.get_height()):.0f}' for v in c]
###  ax.bar_label(c, labels=labels, label_type='edge', fontsize=12)
    
plt.xlabel('Age groups',fontsize=15)
plt.ylabel('Count',fontsize=15)

plt.xticks(fontsize=13)
plt.yticks(fontsize=13)

plt.title('Number of respondents of different age groups based on Gender', y =1.1)

plt.savefig('age_gender.png')

plt.show()

# %% [markdown]
# ## 2. Conclusión
# La mayor cantidad de respuestas obtenidas fue por las mujeres en un rango de edad de 35-60 años. La menor cantidad de respuestas obtenidas fue por los hombres mayores o igual a 60 años.

# %% [markdown]
# ## Pregunta 3 ¿Cuál es la cantidad de personas satisfechas según el género?

# %%
s=pd.pivot_table(index=['AgeGP','Gender'],
            data=dff,
            aggfunc='count',
            values='Age'
            )
s.Age.sum()
# Out:
# 25976

# %%
import plotly.express as px

# %%
pd.pivot_table(index=['AgeGP','Gender'],
            data=dff,
            aggfunc='count'
            )
# Out:
#                Age  satisfaction
# AgeGP Gender
# 18-35 Female  4205          4205
#       Male    3918          3918
# 35-60 Female  6859          6859
#       Male    6755          6755
# <=18  Female  1074          1074
#       Male    1087          1087
# >=60  Female  1034          1034
#       Male    1044          1044

# %%
fig=px.sunburst(dff,
                path=['satisfaction','AgeGP','Gender'],
                title='Satisfacción de los diferentes grupo de edades por género'
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## 3. Conclusión
# La mayor cantidad de personas satisfechas son las mujeres entre 35-60 años, específicamente 3800 mujeres.
# La menor cantidad de personas satisfechas son las mujeres menores de 18 años.
# La mayor cantidad de personas insatisfechas son las mujeres entre 35-60 años.
# La menor cantidad de personas insatisfechas son los hombres mayores o igual a 60 años.

# %% [markdown]
# ## 4. ¿Cómo se ve gráficamente la calificación de los diferentes servicios de la aerolinea?

# %%
sns.boxplot(data=df.loc[:, 
                        ['On-board service','Gender','Checkin service','Inflight wifi service', 'Inflight entertainment', 'Baggage handling']]         
           )

plt.xticks(fontsize=17,
           rotation=45
          )
color_list=['salmon','blue','pink','red','orchid']
plt.title('Calification of the the different services of the Airline ')
plt.show()

# %% [markdown]
# ## 4. Conclusión
#
# El servicio de Baggage handling es el servicio que más alta puntuación tuvo.
# Se puede ver que no hay valores atípicos.

# %% [markdown]
# ## 5. ¿Cómo se ven las calificaciones de 'Cleanliness' respecto a 'Inflight Service' según el género?

# %%
men = (df.Gender == 'M')
women = (df.Gender == 'W')

with sns.axes_style(style=None):
    sns.violinplot(x="Checkin service", 
                   y="Inflight service", 
                   hue="Gender", 
                   data=df,
                   split=True, 
                   inner="quartile",
                   palette=["orchid", "salmon"]
                  );
plt.title('Calificación de Cleanliness y Inflight Service según el género',color='m',y=1.03,fontweight=20)
plt.show()

# %% [markdown]
# ## 5. Conclusión
# Entre más calificación del servicio de 'Chekin service', más calificación del 'Inflight service' para ambos géneros.

# %% [markdown]
# ## 6. Pregunta 6

# %%
fig = plt.figure()

ax1 = fig.add_subplot(121)

sns.kdeplot(df.Cleanliness[df.Gender=='Male'], 
            label='Male', 
            color="salmon",
            fill=True)
ax2 = fig.add_subplot(122, 
                      sharey=ax1 #sharing same y axis with ax1
                     )

sns.kdeplot(df.Cleanliness[df.Gender=='Female'], 
            label='Female', 
            color="orchid",
            fill=True)

ax1.title.set_text('Male Boxplot')
ax2.title.set_text('Female Boxplot')

fig.tight_layout(pad = 0.5) #space between the figures

plt.show()
#plt.title('Calification Cleanliness de la Aerolinea por género', y=1.2);

# %%
sns.kdeplot(df.Cleanliness[df.Gender=='Male'], 
            label='Male', 
            fill=True)
sns.kdeplot(df.Cleanliness[df.Gender=='Female'], 
            label='Female', 
            fill=True)
plt.legend()
plt.xlabel('Calification Cleanliness de la Aerolinea por género');

# %% [markdown]
# ## 6. Conclusión
# El comportamiento de la calificación del servicio de 'Cleanliness' es casi el mismo tanto para hombre como para mujeres. Sin embargo hay una leve diferencia, donde es mayor las puntuaciones de las 'Females'.

# %% [markdown]
# ## 7. ¿Cuál es la calificación de 'Food and Drink' según la edad?

# %%
sns.lmplot(x='Age', 
           y='Food and drink', 
           data=df,
           fit_reg=False,  # No regression line
           #hue='Gender'
           )   # Color by evolution stage

plt.title('Scatterplot Satisfaction of Food and Drink vs Age')
plt.show()

# %% [markdown]
# #7. Conclusión
# La mayoria de personas le dieron la calificación de '5' al 'Food and Drink' de la aerolínea.
# Los que calificaron 'Food and Drink' con calificación de '0' la mayoría tienen edad entre 30-45 años.

# %% [markdown]
# ## 8. ¿Cuál es el 'Class'de las personas que viajan según la edad y el género?

# %%
sns.stripplot(data=df, x="Age", y="Class", order=['Eco Plus',"Business","Eco"], hue="Gender")

plt.title='Clasificación del tipo de Class según el género y la edad'
plt.show()

# %% [markdown]
# # 8. Conclusión
# La mayor cantidad de personas adultas mayores entre 70-80 años viajan en la class 'Business'.
#
# Las personas entre 20-60 tanto hombres como mujeres, viajan de igual manera tanto en 'Eco Plus','Business' y 'Eco'.

# %% [markdown]
# ## 9. Según la edad y el género, ¿Qué personas viajan por 'Buiseness travel' o 'Personal Travel'?

# %%
sns.stripplot(data=df, x="Age", y="Type of Travel", hue="Gender")

plt.title='Clasificación Type of Travel según el género y la edad'
plt.show()

# %% [markdown]
# # 9. Conclusión
# Las personas adultas de 70-80 años tanto mujeres como hombres viajan por 'Business Travle'.
# La mayor cantidad de personas menor de 10 años tanto hombres como mujeres viajan por 'Personal Travel'.

# %% [markdown]
# ## 10. ¿Cuál es el 'Customer Type' de las personas que viajan según la edad y el género?

# %%
sns.stripplot(data=df, x="Age", y="Customer Type", hue="Gender")

plt.title='Clasificación del Customer Type según el género y la edad'
plt.show()

# %% [markdown]
# # 10. Conclusión
#
# La mayoria de personas entre 50-80 años son 'Loyal Customer' tanto hombres como mujeres.
# Los 'loyal Customer' mayores de 80 años es en mayoría de Género masculino.

# %% [markdown]
# ## 11. Regresion
#
# ## ¿ Cuál es la Flight Distance de una persona de edad 35?

# %%
df = df.rename({'Flight Distance': 'FlightD'}, 
                       axis=1
                      )  
df
# Out:
#        Unnamed: 0     id  Gender      Customer Type  Age   Type of Travel  \
# 0               0  19556  Female     Loyal Customer   52  Business travel
# 1               1  90035  Female     Loyal Customer   36  Business travel
# 2               2  12360    Male  disloyal Customer   20  Business travel
# 3               3  77959    Male     Loyal Customer   44  Business travel
# 4               4  36875  Female     Loyal Customer   49  Business travel
# ...           ...    ...     ...                ...  ...              ...
# 25971       25971  78463    Male  disloyal Customer   34  Business travel
# 25972       25972  71167    Male     Loyal Customer   23  Business travel
# 25973       25973  37675  Female     Loyal Customer   17  Personal Travel
# 25974       25974  90086    Male     Loyal Customer   14  Business travel
# 25975       25975  34799  Female     Loyal Customer   42  Personal Travel
#
#           Class  FlightD  Inflight wifi service  \
# ...

# %%
df4=df[['Gender','FlightD','Age']]
df4=df4.dropna()
df4.isnull().any()
# Out:
# Gender     False
# FlightD    False
# Age        False
# dtype: bool

# %%
df4
# Out:
#        Gender  FlightD  Age
# 0      Female      160   52
# 1      Female     2863   36
# 2        Male      192   20
# 3        Male     3377   44
# 4      Female     1182   49
# ...       ...      ...  ...
# 25971    Male      526   34
# 25972    Male      646   23
# 25973  Female      828   17
# 25974    Male     1127   14
# 25975  Female      264   42
#
# [25976 rows x 3 columns]

# %%
modelB=sm.OLS.from_formula('FlightD ~ Age + Gender ',data=df4)
resultB=modelB.fit()
resultB.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                FlightD   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     130.1
# Date:                Tue, 02 May 2023   Prob (F-statistic):           5.93e-57
# Time:                        21:56:13   Log-Likelihood:            -2.1613e+05
# No. Observations:               25976   AIC:                         4.323e+05
# Df Residuals:                   25973   BIC:                         4.323e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %% [markdown]
# Flight Distance = b0 + b1*Age    y=c+mx

# %%
print('Flight Distance of a person with age 35 is',939.8064+ 	6.5629*35)
# Out:
# Flight Distance of a person with age 35 is 1169.5079

# %%
hm = plt.subplots(figsize=(12, 7))
hm = sns.heatmap(df4.corr(), 
           annot = True, 
           linewidth=0.5,
            cmap = 'Reds', 
            annot_kws={"size": 17}, 
                 cbar_kws={"orientation": "horizontal"},
           )

hm.set_yticklabels(hm.get_ymajorticklabels(), 
                   fontsize = 17, 
                  )
hm.set_yticklabels(hm.get_ymajorticklabels(), 
                   fontsize = 17, 
                   rotation = 15
                  )
hm.tick_params(#axis='y', 
               right=True,  # a line will appear if it is true 
               labelleft=False, 
               labelright=True, 
              )
#to place the top lables in 'left' position
ylables = hm.get_yticklabels()#which='both')
for i in ylables:
    i.set_va('bottom')

hm.set_xticklabels(hm.get_xmajorticklabels(), 
                   fontsize = 17, 
                   rotation = 15
                  )
hm.tick_params(#axis='x', 
               top=True,  # a line will appear if it is true 
               labeltop=True, 
               labelbottom=False, 
              )


#to place the top lables in 'left' position
ticklbls = hm.get_xticklabels()#which='both')
for x in ticklbls:
    x.set_ha('left')
# Out:
# <ipython-input-43-617959e0a62c>:2: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.

# %% [markdown]
# ## 11. Conclusion
#
# Los heatmaps visualizan los elementos más populares (color rojo intenso) y menos populares (color rosa) de las variables, donde la variable Age con Flight Distance tiene una relación de 0.099, de color rosa, es decir no tiene una relación fuerte.

# %% [markdown]
# ## 12. Regresión
# ## ¿Qué tan fuerte es la relación de las variables de Servicio 'Cleanliness' y 'Flight Distance?

# %%
df6=df[['Cleanliness','FlightD']]

# %%
##plt.figure(figsize=(15, 10)) 

sns.set(font_scale=1.5)

ax = sns.regplot(x='Cleanliness',     # Salary = b0 + b1*Age
                 y='FlightD', 
                 data=df6, 
                 color='magenta', 
                 marker='+', 
                 scatter_kws={'s': 200}
                )

ax.set(xlabel='Cleanliness', 
       ylabel='Flight Distance'
      )

## ax.text(45, 1450, 'Salary = b0 + b1* Age',  horizontalalignment='left', size='medium', color='black', weight='semibold')
ax.set_title('Regression plot Cleanliness vs Flight Distance')
plt.show()

# %% [markdown]
# ## 12. Conclusión
#
# Se puede ver como las variables de 'Cleanliness' y 'Flight Distance', no siguen la linea de regresión. Se forman lineas de forma vertical, casi paralela a la linea de regresión.
